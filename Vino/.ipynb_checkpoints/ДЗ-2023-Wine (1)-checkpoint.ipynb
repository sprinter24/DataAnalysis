# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
pd.set_option('max_colwidth', 500)
np.random.seed(112)

# %%
students = pd.read_excel("Новая таблица.xlsx")
students.insert(1,'Сравнить', np.random.choice(['Какой год 2011-2014 самый удачный или неудачный или они все одинаковые для французского Бордо?',
                                                'Вино 2010 года в какой из стран - Италия,  Франция, Чили лучше/хуже всего или однородны?',
                                                'Вино в какой из стран - Молдавия, Румыния, Турция лучше/хуже всего или однородны?',
                                                "Итальянские Montepulciano, Nero d'Avola, Pinot Noir+Pinot Nero  - сравнить",
"Самое популярное итальянское Sangiovese, французское Burgundy, и калифорнийское (не самое популяное, но оно там есть) Pinot Noir - сравнить",
"Испанское, Аргентинское и Бургундское  - сравнить",
"В ценовой категории 10-20(мб чуть расширить?) сравнить итальянское, испанское, французское(мб разделить на Бордо и остальное?), чилийское",
                                                "Сравнить года 2012, 13, 14 для Каберне в Калифорнии",
"Вино в какой из стран - Португалия, Канада, Греция лучше/хуже всего или однородны?",
"Сравнить по странам вино с маркировкой Reserve, быть может, объединяя некоторые страны",
"В ценовой категории 70-150(быть может, чуть подвигать, но по смыслу - дорогое вино) сравнить Калифорнию, Францию и Италию+Испания(мб сюда добавить еще какие-то страны, если численности совсем сильно будут различаться)",
"Испанское вино по ценовым категориям до 15, 15-30, 30-45"],size = len(students)))

# %%
students
# Out:
#           Аркунова Ирина   \
# 0        Бондарев Никита
# 1         Васильев Никита
# 2  Ломоносова Александра
# 3            Любин Даниил
# 4          Лютый Дмитрий
# 5           Монина Дарья
# 6         Нежиков Кирилл
# 7       Парфёнова Татьяна
# 8        Полесский Максим
# 9       Шалимова Виктория
#
#                                                                                                                                                                                                                     Сравнить
# 0                                                                                Самое популярное итальянское Sangiovese, французское Burgundy, и калифорнийское (не самое популяное, но оно там есть) Pinot Noir - сравнить
# 1                                                                                                                                                                   Испанское вино по ценовым категориям до 15, 15-30, 30-45
# ...

# %% [markdown]
# ### Для сравнения выборок проверить их нормальность и применить допустимые критерии, сравнивать и по непрерывной величине и чисто по оценкам (посмотрев на образец)) Пример содержится в файле Wine_Late.ipynb
